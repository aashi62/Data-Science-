# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv("churn_modelling.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
x= data.iloc[ :, 3: -1]
y= data.iloc[ :,-1: ]

# %%
x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
y
# Out:
#       Exited
# 0          1
# 1          0
# 2          1
# 3          0
# 4          0
# ...      ...
# 9995       0
# 9996       0
# 9997       1
# 9998       1
# 9999       0
#
# [10000 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
x['Gender']= le.fit_transform(x['Gender'])

# %%
x['Geography'] = le.fit_transform(x['Geography'])

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x= sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y, random_state=42)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
ann= Sequential()

# %%
ann.add(Dense(units=11, activation= 'relu')) #first hidden layer

# %%
ann.add(Dense(units=6, activation= 'relu')) #second hidden layer

# %%
ann.add(Dense(units=1, activation= 'sigmoid')) #output layer

# %% [markdown]
# Training the ANN

# %% [markdown]
# Compiling the ANN

# %%
ann.compile(optimizer= 'adam', loss= 'binary_crossentropy', metrics= ['accuracy'])

# %% [markdown]
# Training the ANN on the training set

# %%
ann.fit(x_train, y_train, batch_size= 32, epochs= 50)
# Out:
# Epoch 1/50
# 235/235 [==============================] - 3s 3ms/step - loss: 0.5738 - accuracy: 0.7847
# Epoch 2/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.4722 - accuracy: 0.7967
# Epoch 3/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.4291 - accuracy: 0.8053
# Epoch 4/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.4102 - accuracy: 0.8189
# Epoch 5/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3957 - accuracy: 0.8311
# Epoch 6/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3853 - accuracy: 0.8375
# Epoch 7/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3778 - accuracy: 0.8408
# Epoch 8/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.3724 - accuracy: 0.8429
# Epoch 9/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3686 - accuracy: 0.8489
# Epoch 10/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.3656 - accuracy: 0.8499
# Epoch 11/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.3628 - accuracy: 0.8508
# Epoch 12/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3613 - accuracy: 0.8531
# Epoch 13/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3595 - accuracy: 0.8528
# Epoch 14/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3579 - accuracy: 0.8537
# Epoch 15/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3573 - accuracy: 0.8541
# Epoch 16/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3561 - accuracy: 0.8552
# Epoch 17/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3544 - accuracy: 0.8549
# Epoch 18/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3542 - accuracy: 0.8577
# Epoch 19/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.3530 - accuracy: 0.8564
# Epoch 20/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3527 - accuracy: 0.8565
# Epoch 21/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3523 - accuracy: 0.8564
# Epoch 22/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3515 - accuracy: 0.8563
# Epoch 23/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3511 - accuracy: 0.8561
# Epoch 24/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3504 - accuracy: 0.8568
# Epoch 25/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3500 - accuracy: 0.8572
# Epoch 26/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.8564
# Epoch 27/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3498 - accuracy: 0.8577
# Epoch 28/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.3485 - accuracy: 0.8564
# Epoch 29/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3486 - accuracy: 0.8572
# Epoch 30/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.3486 - accuracy: 0.8563
# Epoch 31/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3482 - accuracy: 0.8563
# Epoch 32/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3478 - accuracy: 0.8563
# Epoch 33/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3476 - accuracy: 0.8577
# Epoch 34/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.3475 - accuracy: 0.8599
# Epoch 35/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.3472 - accuracy: 0.8580
# Epoch 36/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3467 - accuracy: 0.8580
# Epoch 37/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3465 - accuracy: 0.8575
# Epoch 38/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3462 - accuracy: 0.8567
# Epoch 39/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3465 - accuracy: 0.8568
# Epoch 40/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.3459 - accuracy: 0.8567
# Epoch 41/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.3460 - accuracy: 0.8584
# Epoch 42/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3451 - accuracy: 0.8579
# Epoch 43/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3453 - accuracy: 0.8580
# Epoch 44/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3449 - accuracy: 0.8579
# Epoch 45/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.3452 - accuracy: 0.8591
# Epoch 46/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3448 - accuracy: 0.8583
# Epoch 47/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3442 - accuracy: 0.8580
# Epoch 48/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3442 - accuracy: 0.8568
# Epoch 49/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3441 - accuracy: 0.8571
# Epoch 50/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3438 - accuracy: 0.8579

# %%
print(y_test)
# Out:
#       Exited
# 6252       0
# 4684       0
# 1731       0
# 4742       0
# 4521       0
# ...      ...
# 4862       0
# 7025       1
# 7647       0
# 7161       0
# 73         0
#
# [2500 rows x 1 columns]
