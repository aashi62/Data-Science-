# %%
weather_data= {
    'day': ['1/1/2017', '1/2/2017', '1/3/2017', '1/4/2017', '1/5/2017', '1/6/2017'],
    'temperature': ['32', '35', '28', '24', '32', '31'],
    'windspeed': ['6','7', '2', '7', '4', '2'],
    'event': ['rain', 'sunny', 'snow', 'snow', 'rain', 'sunny']
}

# %%
import pandas as pd
df= pd.DataFrame(weather_data)
df
# Out:
#         day temperature windspeed  event
# 0  1/1/2017          32         6   rain
# 1  1/2/2017          35         7  sunny
# 2  1/3/2017          28         2   snow
# 3  1/4/2017          24         7   snow
# 4  1/5/2017          32         4   rain
# 5  1/6/2017          31         2  sunny

# %%
df.to_csv('aashi.csv')

# %%
df.shape
# Out:
# (6, 4)

# %%
#print shape with strong variable
rows, column= df.shape
print("rows=",rows)
print("column=",column)
# Out:
# rows= 6
# column= 4

# %%
df.head()
# Out:
#         day temperature windspeed  event
# 0  1/1/2017          32         6   rain
# 1  1/2/2017          35         7  sunny
# 2  1/3/2017          28         2   snow
# 3  1/4/2017          24         7   snow
# 4  1/5/2017          32         4   rain

# %%
df.head(2)
# Out:
#         day temperature windspeed  event
# 0  1/1/2017          32         6   rain
# 1  1/2/2017          35         7  sunny

# %%
df.tail()
# Out:
#         day temperature windspeed  event
# 1  1/2/2017          35         7  sunny
# 2  1/3/2017          28         2   snow
# 3  1/4/2017          24         7   snow
# 4  1/5/2017          32         4   rain
# 5  1/6/2017          31         2  sunny

# %%
df[2:6]
# Out:
#         day temperature windspeed  event
# 2  1/3/2017          28         2   snow
# 3  1/4/2017          24         7   snow
# 4  1/5/2017          32         4   rain
# 5  1/6/2017          31         2  sunny

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df1= df[['day','temperature']] #df[]

# %%
df1
# Out:
#         day temperature
# 0  1/1/2017          32
# 1  1/2/2017          35
# 2  1/3/2017          28
# 3  1/4/2017          24
# 4  1/5/2017          32
# 5  1/6/2017          31

# %%
#axis 1  means select columns, 0 means select rows
df2= df.drop(['windspeed', 'event'], axis=1)

# %%
df2
# Out:
#         day temperature
# 0  1/1/2017          32
# 1  1/2/2017          35
# 2  1/3/2017          28
# 3  1/4/2017          24
# 4  1/5/2017          32
# 5  1/6/2017          31

# %%
df.temperature.min()
# Out:
# '24'

# %%
df.temperature.max()
# Out:
# '35'

# %%
df.describe()
#statistical values
# Out:
#              day temperature windspeed event
# count          6           6         6     6
# unique         6           5         4     3
# top     1/1/2017          32         7  rain
# freq           1           2         2     2

# %%
student_data= {
    'Name': ['aashi', 'tashi', 'mishri', 'tiku', 'chinku', 'koyal'],
    'Class': ['12', '11', '11', '12', '11', '12'],
    'Stream': ['Science','Commerce', 'Arts', 'Science', 'Arts', 'Science'],
    'City': ['Ahmedabad', 'diu', 'baroda', 'navsari', 'gandhingar', 'rajkot']
}

# %%
import pandas as pd
df4= pd.DataFrame(student_data)
df4
# Out:
#      Name Class    Stream        City
# 0   aashi    12   Science   Ahmedabad
# 1   tashi    11  Commerce         diu
# 2  mishri    11      Arts      baroda
# 3    tiku    12   Science     navsari
# 4  chinku    11      Arts  gandhingar
# 5   koyal    12   Science      rajkot

# %%
pd.concat([df,df4], axis=1, join= 'inner')
# Out:
#         day temperature windspeed  event    Name Class    Stream        City
# 0  1/1/2017          32         6   rain   aashi    12   Science   Ahmedabad
# 1  1/2/2017          35         7  sunny   tashi    11  Commerce         diu
# 2  1/3/2017          28         2   snow  mishri    11      Arts      baroda
# 3  1/4/2017          24         7   snow    tiku    12   Science     navsari
# 4  1/5/2017          32         4   rain  chinku    11      Arts  gandhingar
# 5  1/6/2017          31         2  sunny   koyal    12   Science      rajkot

# %%
df5= df.append(df4)
# Out:
# <ipython-input-57-e8c388141695>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df5= df.append(df4)

# %%
df5
# Out:
#         day temperature windspeed  event    Name Class    Stream        City
# 0  1/1/2017          32         6   rain     NaN   NaN       NaN         NaN
# 1  1/2/2017          35         7  sunny     NaN   NaN       NaN         NaN
# 2  1/3/2017          28         2   snow     NaN   NaN       NaN         NaN
# 3  1/4/2017          24         7   snow     NaN   NaN       NaN         NaN
# 4  1/5/2017          32         4   rain     NaN   NaN       NaN         NaN
# 5  1/6/2017          31         2  sunny     NaN   NaN       NaN         NaN
# 0       NaN         NaN       NaN    NaN   aashi    12   Science   Ahmedabad
# 1       NaN         NaN       NaN    NaN   tashi    11  Commerce         diu
# 2       NaN         NaN       NaN    NaN  mishri    11      Arts      baroda
# 3       NaN         NaN       NaN    NaN    tiku    12   Science     navsari
# 4       NaN         NaN       NaN    NaN  chinku    11      Arts  gandhingar
# ...

# %%
df5.shape
# Out:
# (12, 8)

# %%
pd.concat([df,df4], axis=0)
# Out:
#         day temperature windspeed  event    Name Class    Stream        City
# 0  1/1/2017          32         6   rain     NaN   NaN       NaN         NaN
# 1  1/2/2017          35         7  sunny     NaN   NaN       NaN         NaN
# 2  1/3/2017          28         2   snow     NaN   NaN       NaN         NaN
# 3  1/4/2017          24         7   snow     NaN   NaN       NaN         NaN
# 4  1/5/2017          32         4   rain     NaN   NaN       NaN         NaN
# 5  1/6/2017          31         2  sunny     NaN   NaN       NaN         NaN
# 0       NaN         NaN       NaN    NaN   aashi    12   Science   Ahmedabad
# 1       NaN         NaN       NaN    NaN   tashi    11  Commerce         diu
# 2       NaN         NaN       NaN    NaN  mishri    11      Arts      baroda
# 3       NaN         NaN       NaN    NaN    tiku    12   Science     navsari
# 4       NaN         NaN       NaN    NaN  chinku    11      Arts  gandhingar
# ...
